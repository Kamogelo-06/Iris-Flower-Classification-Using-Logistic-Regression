# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataset
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Independent Variable
X = df.drop(['Id', 'Species'], axis=1)

# %%
# Encode the dependent variable
y = df['Species'].apply(lambda x: 0 if x == 'Iris-setosa' else 1)

# %%
# Split the data into a training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# fit a model and make predictions on the test set

from sklearn.linear_model import LogisticRegression

# Initialioze model
model = LogisticRegression()

# Fit the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
# Generate a confusion matrix, which compares the predicted labels to the 
# actual labels (goldlabels)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[15  0]
#  [ 0 23]]

# %%
# Analyse the confusion matrix and provide a prediction

# The model shows perfect classification performance on the test set, 
# with zero false positives and false negatives

# %%
# Calculate the accuracy, precision, and recall, and check 
# whether your prediction was right

from sklearn.metrics import accuracy_score, precision_score, recall_score

# Confusion Matrix
TN = 15  # True Negatives
FP = 0   # False Positives
FN = 0   # False Negatives
TP = 23  # True Positives

# Precision
precision = TP / (TP + FP) if (TP + FP) > 0 else 0

# Recall
recall = TP / (TP + FN) if (TP + FN) > 0 else 0 

# Accuracy
accuracy = (TP + TN) / (TP + TN + FP + FN)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")

# Yes, prediction was right, as the model achieved an accuracy of 100% on the test set.
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
